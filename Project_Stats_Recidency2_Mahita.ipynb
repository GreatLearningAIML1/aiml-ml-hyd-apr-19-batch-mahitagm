# %%
import pandas as pd
import numpy as np

tt = pd.read_csv('titan.csv')

# %%
tt.head()
# Out:
#    SALES_PERSON  Old_Scheme  New_Scheme
# 0             1          57          62
# 1             2         103         122
# 2             3          59          54
# 3             4          75          82
# 4             5          84          84

# %%
tt.describe()
# Out:
#        SALES_PERSON  Old_Scheme  New_Scheme
# count     30.000000   30.000000   30.000000
# mean      15.500000   68.033333   72.033333
# std        8.803408   20.455980   24.062395
# min        1.000000   28.000000   32.000000
# 25%        8.250000   54.000000   55.000000
# 50%       15.500000   67.000000   74.000000
# 75%       22.750000   81.500000   85.750000
# max       30.000000  110.000000  122.000000

# %%
tt['Old_Scheme'].mean()
# Out:
# 68.03333333333333

# %%
tt['New_Scheme'].mean()
# Out:
# 72.03333333333333

# %%
import pandas as pd
import numpy as np
from scipy.stats import ttest_1samp, wilcoxon
from statsmodels.stats.power import ttest_power
from scipy.stats import ttest_1samp, ttest_ind, mannwhitneyu, levene, shapiro
from statsmodels.stats.power import ttest_power

# %%
t_statistic, p_value = ttest_ind(tt['Old_Scheme'], tt['New_Scheme'])
print(t_statistic, p_value)
# Out:
# -0.6937067608923764 0.49063515686248105

# %%
## pvalue is >0.05 Hence we cannot reject the null hypothesis 
# old scheme and new scheme are significantaly same , which means they have same mean and we are 95% confident of that
#which also means that new_scheme has not significantly raised outputs

# %%
tt['Old_Scheme']-tt['New_Scheme']
# Out:
# 0     -5
# 1    -19
# 2      5
# 3     -7
# 4      0
# 5    -13
# 6      3
# 7      6
# 8      6
# 9    -25
# 10   -17
# 11   -21
# 12   -21
# 13    14
# 14     7
# 15   -19
# 16     7
# 17    34
# 18     7
# 19   -13
# 20   -13
# 21    -9
# 22    11
# 23   -11
# 24   -18
# 25    19
# 26    -8
# 27     7
# 28    -9
# 29   -18
# dtype: int64

# %%
t_statistic,p_value = ttest_1samp((tt['Old_Scheme']-tt['New_Scheme'])-50,0)

# %%
print(p_value)
# Out:
# 4.3304329413665686e-19

# %%
import numpy as np
from scipy.stats import ttest_1samp, ttest_ind, mannwhitneyu, levene, shapiro
from statsmodels.stats.power import ttest_power
(np.mean(tt['Old_Scheme']) - np.mean(tt['New_Scheme'])) / np.sqrt(((11-1)*np.var(tt['Old_Scheme'])+(11-1)*np.var(tt['New_Scheme'])) / 11+11-2)
# Out:
# -0.13441726595582315
