# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df.head()
# Out:
#   City City2  Average_Fare  Distance  Average_weekly_passengers  \
# 0  CAK   ATL        114.47       528                     424.56
# 1  CAK   MCO        122.47       860                     276.84
# 2  ALB   ATL        214.42       852                     215.76
# 3  ALB   BWI         69.40       288                     606.84
# 4  ALB   ORD        158.13       723                     313.04
#
#   market_leading_airline  market_share  Average_fare  Low_price_airline  \
# 0                     FL         70.19         111.03                FL
# 1                     FL         75.10         123.09                DL
# 2                     DL         78.89         223.98                CO
# 3                     WN         96.97          68.86                WN
# 4                     UA         39.79         161.36                WN
#
#    market_share.1   price
# 0           70.19  111.03
# 1           17.23  118.94
# 2            2.77  167.12
# 3           96.97   68.86
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
# City                         1000 non-null object
# City2                        1000 non-null object
# Average_Fare                 1000 non-null float64
# Distance                     1000 non-null int64
# Average_weekly_passengers    1000 non-null float64
# market_leading_airline       1000 non-null object
# market_share                 1000 non-null float64
# Average_fare                 1000 non-null float64
# Low_price_airline            1000 non-null object
# market_share.1               1000 non-null float64
# price                        1000 non-null float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 86.0+ KB

# %%
df.describe()
# Out:
#        Average_Fare     Distance  Average_weekly_passengers  market_share  \
# count    1000.00000  1000.000000                1000.000000   1000.000000
# mean      163.37542  1056.973000                 672.279140     60.128590
# std        55.36547   643.203251                 766.519254     19.367779
# min        50.52000   108.000000                 181.410000     17.680000
# 25%       125.97500   553.500000                 257.197500     46.510000
# 50%       161.34500   919.000000                 404.780000     59.240000
# 75%       197.39250  1452.500000                 769.912500     73.510000
# max       401.23000  2724.000000                8950.760000    100.000000
#
#        Average_fare   market_share.1        price
# count     1000.00000     1000.000000  1000.000000
# mean       166.64756       34.551480   143.193090
# std         62.66014       27.096999    47.229184
# min         50.52000        1.060000    49.610000
# ...

# %%
AF_l = df['Average_Fare'].quantile(.25)*1.5
AF_l
# Out:
# 188.96249999999998

# %%
AF_o = df['Average_Fare'].quantile(.75)*1.5
AF_o
# Out:
# 296.08875

# %%
dis_l = df['Distance'].quantile(.25)*1.5
dis_l
# Out:
# 830.25

# %%
dis_o = df['Distance'].quantile(.75)*1.5
dis_o
# Out:
# 2178.75

# %%
awp_l = df['Average_weekly_passengers'].quantile(.25)*1.5
awp_l
# Out:
# 385.79625

# %%
awp_o = df['Average_weekly_passengers'].quantile(.75)*1.5
awp_o
# Out:
# 1154.8687499999999

# %%
ms_l = df['market_share'].quantile(.25)*1.5
ms_l
# Out:
# 69.765

# %%
ms_o = df['market_share'].quantile(.75)*1.5
ms_o
# Out:
# 110.26500000000001

# %%
pr_l = df['price'].quantile(.25)*1.5
pr_l
# Out:
# 170.65125

# %%
pr_o = df['price'].quantile(.75)*1.5
pr_o
# Out:
# 252.79500000000004

# %%
#df.drop(df[df['Average_Fare'] < AF_l].index, inplace = True)

# %%
#df.drop(df[df['Average_Fare'] > AF_o].index, inplace = True)

# %%
df.drop(df[df['Distance'] < dis_l].index, inplace = True)

# %%
df.drop(df[df['Distance'] > dis_o].index, inplace = True)

# %%
df.drop(df[df['Average_weekly_passengers'] < awp_l].index, inplace = True)

# %%
df.drop(df[df['Average_weekly_passengers'] > awp_o].index, inplace = True)

# %%
df.drop(df[df['market_share'] < ms_l].index, inplace = True)

# %%
df.drop(df[df['market_share'] > ms_o].index, inplace = True)

# %%
df.drop(df[df['price'] < pr_l].index, inplace = True)

# %%
df.drop(df[df['price'] > pr_o].index, inplace = True)

# %%
df.describe()
# Out:
#        Average_Fare     Distance  Average_weekly_passengers  market_share  \
# count      6.000000     6.000000                   6.000000      6.000000
# mean     220.396667  1350.166667                 586.518333     79.706667
# std       13.067604   227.684358                 169.453864      9.409845
# min      204.220000  1107.000000                 431.410000     72.550000
# 25%      212.937500  1145.750000                 485.895000     74.940000
# 50%      220.570000  1345.500000                 512.170000     75.820000
# 75%      223.275000  1559.500000                 661.872500     80.045000
# max      242.450000  1593.000000                 874.450000     97.950000
#
#        Average_fare   market_share.1       price
# count       6.000000        6.000000    6.000000
# mean      226.321667       23.231667  189.753333
# std        15.887107       36.802772   13.618137
# min       202.790000        3.010000  175.960000
# 25%       220.515000        5.980000  181.452500
# ...

# %%
df.head()
# Out:
#    City City2  Average_Fare  Distance  Average_weekly_passengers  \
# 2   ALB   ATL        214.42       852                     215.76
# 7   ALB   LAX        190.73      2467                     191.95
# 10  ABQ   ATL        212.49      1269                     198.80
# 19  ABQ   LGA        233.05      1825                     344.45
# 27  ABQ   IAD        227.93      1650                     301.84
#
#    market_leading_airline  market_share  Average_fare  Low_price_airline  \
# 2                      DL         78.89         223.98                CO
# 7                      DL         17.89         205.06                US
# 10                     DL         68.39         226.79                AA
# 19                     AA         31.33         233.26                DL
# 27                     AA         46.59         213.13                AA
#
#     market_share.1   price
# 2             2.77  167.12
# 7            16.59  174.00
# 10           11.91  200.93
# ...
